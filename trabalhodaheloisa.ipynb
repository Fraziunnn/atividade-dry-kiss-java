# %% [markdown]
# <a href="https://colab.research.google.com/github/Fraziunnn/atividade-dry-kiss-java/blob/main/trabalhodaheloisa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importação das bibliotecas principais

import pandas as pd
import numpy as np
print ("Bibliotecas importadas com sucesso")
# Out:
# Bibliotecas importadas com sucesso

# %%
df = pd.read_csv("/content/boardgame-geek-dataset_organized.csv")

# %%
#Exibindo as primeiras linhas
print("Primeiras 5 linhas do dataset")
print(df.head())
# Out:
# Primeiras 5 linhas do dataset
#    row_id                          boardgame  release_year  min_players  \
# 0       1                  Brass: Birmingham          2018            2
# 1       2          Pandemic Legacy: Season 1          2015            2
# 2       3                           Ark Nova          2021            1
# 3       4                         Gloomhaven          2017            1
# 4       5  Twilight Imperium: Fourth Edition          2017            3
#
#    max_players  min_playtime  max_playtime  minimum_age  avg_rating  \
# 0            4            60           120           14       8.575
# 1            4            60            60           13       8.512
# 2            4            90           150           14       8.539
# 3            4            60           120           14       8.557
# 4            6           240           480           14       8.572
#
#    num_ratings  ...  rank_strategy  rank_thematic  rank_family  rank_war  \
# ...

# %%
print("\n" + "=" * 50)
print("Informações do dataset")
print(df.info())
# Out:
# ...
# Informações do dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 57 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   row_id             2000 non-null   int64
#  1   boardgame          2000 non-null   object
#  2   release_year       2000 non-null   int64
#  3   min_players        2000 non-null   int64
#  4   max_players        2000 non-null   int64
#  5   min_playtime       2000 non-null   int64
#  6   max_playtime       2000 non-null   int64
#  7   minimum_age        2000 non-null   int64
#  8   avg_rating         2000 non-null   float64
#  9   num_ratings        2000 non-null   int64
#  10  complexity         2000 non-null   float64
#  11  rank_overall       2000 non-null   int64
#  12  owned              2000 non-null   int64
#  13  wishlisted         2000 non-null   int64
#  14  total_plays        2000 non-null   int64
# ...

# %%
# Estatísticas descritivas para colunas numéricas
print("\n" + "=" * 50)
print("Estatísticas descritivas das colunas numéricas:")
print(df.describe())
# Out:
# ...
# Estatísticas descritivas das colunas numéricas:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3750089780.py in <cell line: 0>()
#       2 print("\n" + "=" * 50)
#       3 print("Estatísticas descritivas das colunas numéricas:")
# ----> 4 print(df.describe())
#
# NameError: name 'df' is not defined

# %%
print("\n" + "=" * 50)
print("Resumo estatístico das colunas numéricas")
print(df.describe())
# Out:
# ...
# Resumo estatístico das colunas numéricas
#             row_id  release_year  min_players  max_players  min_playtime  \
# count  2000.000000   2000.000000  2000.000000  2000.000000   2000.000000
# mean   1000.500000   2010.398500     1.764000     4.944000     57.519000
# std     577.494589     80.765724     0.708911     6.112655     48.646129
# min       1.000000      0.000000     1.000000     1.000000      0.000000
# 25%     500.750000   2011.000000     1.000000     4.000000     30.000000
# 50%    1000.500000   2017.000000     2.000000     4.000000     45.000000
# 75%    1500.250000   2020.000000     2.000000     5.000000     60.000000
# max    2000.000000   2025.000000     8.000000   100.000000    480.000000
#
#        max_playtime  minimum_age   avg_rating    num_ratings   complexity  \
# count   2000.000000  2000.000000  2000.000000    2000.000000  2000.000000
# mean      88.699000    11.342500     7.420455    9244.914000     2.537535
# ...

# %%
print("\n" + "=" * 50)
print("Resumo estatístico das colunas categóricas")
print(df.describe(include=['object']))
# Out:
# ...
# Resumo estatístico das colunas categóricas
#        boardgame categories         mechanics                   families  \
# count       2000       1995              1997                       1989
# unique      1985       1227              1849                       1944
# top      Oceanos  Card Game  Cooperative Game  Crowdfunding: Kickstarter
# freq           2         32                10                          6
#
#             designers        artists publishers    solo_designers  \
# count            1997           1941       2000               163
# unique           1128           1426       1878                93
# top     Reiner Knizia  Klemens Franz  GMT Games  ['Dávid Turczi']
# freq               44             26         14                13
#
#                 developers graphic_designers                     sculptors  \
# count                  532               643                           118
# ...

# %%
# Mostrar as 5 primeiras linhas
print("🔹 Primeiras 5 linhas do DataFrame:")
print(df.head())
# Out:
# 🔹 Primeiras 5 linhas do DataFrame:
#    row_id                          boardgame  release_year  min_players  \
# 0       1                  Brass: Birmingham          2018            2
# 1       2          Pandemic Legacy: Season 1          2015            2
# 2       3                           Ark Nova          2021            1
# 3       4                         Gloomhaven          2017            1
# 4       5  Twilight Imperium: Fourth Edition          2017            3
#
#    max_players  min_playtime  max_playtime  minimum_age  avg_rating  \
# 0            4            60           120           14       8.575
# 1            4            60            60           13       8.512
# 2            4            90           150           14       8.539
# 3            4            60           120           14       8.557
# 4            6           240           480           14       8.572
#
#    num_ratings  ...  rank_strategy  rank_thematic  rank_family  rank_war  \
# ...

# %%
# Informações gerais do DataFrame
print("\n🔹 Informações do DataFrame:")
print(df.info())
# Out:
# 🔹 Informações do DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 57 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   row_id             2000 non-null   int64
#  1   boardgame          2000 non-null   object
#  2   release_year       2000 non-null   int64
#  3   min_players        2000 non-null   int64
#  4   max_players        2000 non-null   int64
#  5   min_playtime       2000 non-null   int64
#  6   max_playtime       2000 non-null   int64
#  7   minimum_age        2000 non-null   int64
#  8   avg_rating         2000 non-null   float64
#  9   num_ratings        2000 non-null   int64
#  10  complexity         2000 non-null   float64
#  11  rank_overall       2000 non-null   int64
#  12  owned              2000 non-null   int64
#  13  wishlisted         2000 non-null   int64
#  14  total_plays        2000 non-null   int64
# ...

# %%
# Estatísticas descritivas numéricas
print("\n🔹 Estatísticas descritivas (colunas numéricas):")
print(df.describe())
# Out:
# 🔹 Estatísticas descritivas (colunas numéricas):
#             row_id  release_year  min_players  max_players  min_playtime  \
# count  2000.000000   2000.000000  2000.000000  2000.000000   2000.000000
# mean   1000.500000   2010.398500     1.764000     4.944000     57.519000
# std     577.494589     80.765724     0.708911     6.112655     48.646129
# min       1.000000      0.000000     1.000000     1.000000      0.000000
# 25%     500.750000   2011.000000     1.000000     4.000000     30.000000
# 50%    1000.500000   2017.000000     2.000000     4.000000     45.000000
# 75%    1500.250000   2020.000000     2.000000     5.000000     60.000000
# max    2000.000000   2025.000000     8.000000   100.000000    480.000000
#
#        max_playtime  minimum_age   avg_rating    num_ratings   complexity  \
# count   2000.000000  2000.000000  2000.000000    2000.000000  2000.000000
# mean      88.699000    11.342500     7.420455    9244.914000     2.537535
# ...

# %%
# Estatísticas descritivas para colunas categóricas
print("\n🔹 Estatísticas descritivas (colunas categóricas):")
print(df.describe(include='object'))
# Out:
# 🔹 Estatísticas descritivas (colunas categóricas):
#        boardgame categories         mechanics                   families  \
# count       2000       1995              1997                       1989
# unique      1985       1227              1849                       1944
# top      Oceanos  Card Game  Cooperative Game  Crowdfunding: Kickstarter
# freq           2         32                10                          6
#
#             designers        artists publishers    solo_designers  \
# count            1997           1941       2000               163
# unique           1128           1426       1878                93
# top     Reiner Knizia  Klemens Franz  GMT Games  ['Dávid Turczi']
# freq               44             26         14                13
#
#                 developers graphic_designers                     sculptors  \
# count                  532               643                           118
# ...

# %%
# Nota média dos jogos (avg_rating)
nota_media = df['avg_rating'].mean()
print(f"\n➡️ Nota média dos jogos: {nota_media:.2f}")
# Out:
# ➡️ Nota média dos jogos: 7.42

# %%
# Calcular tempo médio de jogo aproximado (média entre min_playtime e max_playtime)
df['avg_playtime'] = (df['min_playtime'] + df['max_playtime']) / 2

# %%
tempo_medio = df['avg_playtime'].mean()
tempo_std = df['avg_playtime'].std()

# %%
print(f"➡️ Tempo médio de jogo: {tempo_medio:.2f} minutos")
print(f"➡️ Desvio padrão do tempo de jogo: {tempo_std:.2f} minutos")
# Out:
# ➡️ Tempo médio de jogo: 73.11 minutos
# ➡️ Desvio padrão do tempo de jogo: 62.95 minutos

# %%
# Valores nulos por coluna
print("\n🔹 Valores nulos por coluna:")
print(df.isnull().sum())
# Out:
# 🔹 Valores nulos por coluna:
# row_id                  0
# boardgame               0
# release_year            0
# min_players             0
# max_players             0
# min_playtime            0
# max_playtime            0
# minimum_age             0
# avg_rating              0
# num_ratings             0
# complexity              0
# rank_overall            0
# owned                   0
# wishlisted              0
# total_plays             0
# fans                    0
# page_views              0
# amazon_price          882
# std_deviation           0
# comments                0
# monthly_plays           0
# previously_owned        0
# for_trade               0
# want_trade              0
# rating_1                0
# rating_2                0
# rating_3                0
# rating_4                0
# rating_5                0
# rating_6                0
# rating_7                0
# rating_8                0
# rating_9                0
# rating_10               0
# ...

# %%
# COMENTÁRIOS:
# • Qual é a nota média de um jogo de tabuleiro neste dataset?
#   R: A nota média é aproximadamente {:.2f}
# • Qual é o tempo de jogo médio e o desvio padrão?
#   R: O tempo médio é {:.2f} minutos, com desvio padrão de {:.2f} minutos
# • Existe alguma coluna com valores nulos que possa impactar as análises futuras?
#   R: [Você pode analisar a saída de valores nulos e responder]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# B.1 - Verificar quantidade de valores nulos na coluna 'avg_rating'
nulos_rating = df['avg_rating'].isnull().sum()
print(f"\nValores nulos em 'avg_rating': {nulos_rating}")
# Out:
# Valores nulos em 'avg_rating': 0

# %%
# B.2 - Preencher valores nulos com a mediana (se houver)
if nulos_rating > 0:
    mediana_rating = df['avg_rating'].median()
    df['avg_rating'].fillna(mediana_rating, inplace=True)
    print(f"'avg_rating' preenchido com a mediana: {mediana_rating}")
else:
    print("Nenhum valor nulo encontrado em 'avg_rating'.")
# Out:
# Nenhum valor nulo encontrado em 'avg_rating'.

# %%
# Justificativa:
# A mediana é menos sensível a valores extremos (outliers) do que a média,
# por isso é uma escolha melhor para preencher dados faltantes neste contexto.

# %%
# B.3 - Boxplot para visualizar outliers em 'avg_playtime'
plt.figure(figsize=(10, 5))
sns.boxplot(x=df['avg_playtime'])
plt.title('Boxplot do Tempo Médio de Jogo (avg_playtime)')
plt.xlabel('Tempo Médio de Jogo (minutos)')
plt.show()

# %%
# B.4 - Cálculo do IQR e identificação dos outliers em 'avg_playtime'
Q1 = df['avg_playtime'].quantile(0.25)
Q3 = df['avg_playtime'].quantile(0.75)
IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

outliers = df[(df['avg_playtime'] < limite_inferior) | (df['avg_playtime'] > limite_superior)]
print(f"Número de jogos considerados outliers no tempo médio de jogo: {len(outliers)}")
# Out:
# Número de jogos considerados outliers no tempo médio de jogo: 119

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# C.1 - Histograma da coluna 'avg_rating'
plt.figure(figsize=(10,6))
sns.histplot(df['avg_rating'], bins=30, kde=True, color='skyblue')
plt.title('Distribuição da Nota Média dos Jogos (avg_rating)')
plt.xlabel('Nota Média')
plt.ylabel('Frequência')
plt.grid(True)
plt.show()

# %%
# Comentário:
# A distribuição tende a ser assimétrica (provavelmente positiva),
# pois a maioria dos jogos tem notas médias concentradas em valores menores com alguns altos.

# %%
# C.2 - Histograma da coluna 'avg_playtime' (tempo médio de jogo)
plt.figure(figsize=(10,6))
sns.histplot(df['avg_playtime'], bins=30, kde=True, color='lightgreen')
plt.title('Distribuição do Tempo Médio de Jogo (avg_playtime)')
plt.xlabel('Tempo Médio de Jogo (minutos)')
plt.ylabel('Frequência')
plt.grid(True)
plt.show()

# %%
# Comentário:
# Essa distribuição geralmente é assimétrica positiva, com a maior parte dos jogos tendo
# tempos menores e uma cauda longa para tempos maiores.

# %%
# C.3 - Transformação logarítmica da coluna 'avg_playtime' para reduzir assimetria
df['log_avg_playtime'] = np.log(df['avg_playtime'] + 1)  # +1 para evitar log(0)

plt.figure(figsize=(10,6))
sns.histplot(df['log_avg_playtime'], bins=30, kde=True, color='salmon')
plt.title('Distribuição do Tempo Médio de Jogo após Transformação Logarítmica')
plt.xlabel('Log(Tempo Médio de Jogo + 1)')
plt.ylabel('Frequência')
plt.grid(True)
plt.show()

# %%
# Comentário:
# Após a transformação logarítmica, a distribuição fica mais simétrica, aproximando-se
# de uma distribuição normal, facilitando análises posteriores que pressupõem normalidade.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# D.1 - Gráfico de dispersão: min_players vs max_players
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='min_players', y='max_players', alpha=0.6)
plt.title('Dispersão entre Número Mínimo e Máximo de Jogadores')
plt.xlabel('Número Mínimo de Jogadores')
plt.ylabel('Número Máximo de Jogadores')
plt.grid(True)
plt.show()

# %%
# D.2 - Comentário sobre o gráfico:
# Normalmente, espera-se que haja uma correlação positiva: jogos que suportam mais jogadores mínimos
# tendem a suportar mais jogadores máximos também.

# %%
# D.3 - Matriz de correlação entre colunas numéricas
corr_matrix = df.select_dtypes(include=['number']).corr()

print("\nMatriz de Correlação:\n", corr_matrix)
# Out:
# Matriz de Correlação:
#                       row_id  release_year  min_players  max_players  \
# row_id             1.000000     -0.014429     0.043090     0.005884
# release_year      -0.014429      1.000000    -0.068804    -0.181897
# min_players        0.043090     -0.068804     1.000000     0.098884
# max_players        0.005884     -0.181897     0.098884     1.000000
# min_playtime      -0.037907      0.005583     0.021599    -0.039336
# max_playtime      -0.060282      0.003039    -0.104290    -0.038726
# minimum_age       -0.179940      0.119558    -0.141552    -0.097742
# avg_rating        -0.477495      0.060397    -0.254746    -0.044696
# num_ratings       -0.509106     -0.030488     0.076977     0.035725
# complexity        -0.222102      0.004491    -0.231912    -0.116246
# rank_overall       0.999998     -0.014435     0.043144     0.005868
# owned             -0.487035     -0.021210     0.049335     0.035908
# ...

# %%
# D.4 - Heatmap para visualizar a matriz de correlação
plt.figure(figsize=(14,10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title('Heatmap da Matriz de Correlação das Variáveis Numéricas')
plt.show()

# %%
# D.5 - Comentários (baseado na matriz):
# • Maior correlação positiva: Geralmente entre 'min_playtime' e 'max_playtime' (esperado, tempos relacionados)
# • Correlação mais próxima de zero: Pode ser entre variáveis que não têm relação aparente, como 'avg_rating' e 'min_players' (exemplo)

# %%
# E.1 - Identificar coluna de ano de publicação
print("Colunas com datas ou anos:", [col for col in df.columns if 'year' in col.lower()])
# Out:
# Colunas com datas ou anos: ['release_year']

# %%
# E.2 - Criar coluna 'Decada' (exemplo: 1990, 2000, etc)
df['Decada'] = (df['release_year'] // 10) * 10

# %%
# E.3 - Contagem de jogos por década
jogos_por_decada = df.groupby('Decada').size().reset_index(name='Quantidade de Jogos')

print("\nQuantidade de jogos lançados por década:")
print(jogos_por_decada)
# Out:
# Quantidade de jogos lançados por década:
#     Decada  Quantidade de Jogos
# 0        0                    3
# 1     1470                    1
# 2     1580                    1
# 3     1630                    1
# 4     1800                    1
# 5     1810                    1
# 6     1850                    1
# 7     1870                    1
# 8     1920                    1
# 9     1950                    1
# 10    1960                    2
# 11    1970                    9
# 12    1980                   25
# 13    1990                   74
# 14    2000                  280
# 15    2010                 1031
# 16    2020                  567

# %%
# E.4 - Comentário:
# A década com maior número de lançamentos é aquela com o maior valor na coluna 'Quantidade de Jogos'.
decada_mais_jogos = jogos_por_decada.loc[jogos_por_decada['Quantidade de Jogos'].idxmax()]

print(f"\n➡️ Década com maior número de lançamentos: {int(decada_mais_jogos['Decada'])} "
      f"com {decada_mais_jogos['Quantidade de Jogos']} jogos lançados.")
# Out:
# ➡️ Década com maior número de lançamentos: 2010 com 1031 jogos lançados.
